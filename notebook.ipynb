# %% [markdown]
# # Proyek Analisis Data: Air-Quality-Dataset
# * Nama: A. Zayadi
# * Email: zayadibunawi@gmail.com
# * ID Dicoding: zayadi99

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# * Pertanyaan 1:
#   Bagaimana tren kadar CO di berbagai daerah di China dalam kurun waktu 2013-2017?
#
# * Pertanyaan 2:
#   Kota apa yang paling baik dan paling buruk kondisi udaranya berdasarkan pengukuran konsentrasi PM10 di udara?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering data

# %%
data1_df = pd.read_csv('data/PRSA_Data_Aotizhongxin_20130301-20170228.csv')
data2_df = pd.read_csv('data/PRSA_Data_Changping_20130301-20170228.csv')
data3_df = pd.read_csv('data/PRSA_Data_Dingling_20130301-20170228.csv')
data4_df = pd.read_csv('data/PRSA_Data_Dongsi_20130301-20170228.csv')
data5_df = pd.read_csv('data/PRSA_Data_Guanyuan_20130301-20170228.csv')
data6_df = pd.read_csv('data/PRSA_Data_Gucheng_20130301-20170228.csv')
data7_df = pd.read_csv('data/PRSA_Data_Huairou_20130301-20170228.csv')
data8_df = pd.read_csv('data/PRSA_Data_Nongzhanguan_20130301-20170228.csv')
data9_df = pd.read_csv('data/PRSA_Data_Shunyi_20130301-20170228.csv')
data10_df = pd.read_csv('data/PRSA_Data_Tiantan_20130301-20170228.csv')
data11_df = pd.read_csv('data/PRSA_Data_Wanliu_20130301-20170228.csv')
data12_df = pd.read_csv('data/PRSA_Data_Wanshouxigong_20130301-20170228.csv')

# %%
data1_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
data2_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
data3_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
data4_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
data5_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
data6_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
data7_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
data8_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
data9_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
data10_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
data11_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
data12_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# ### Assesing Data

# %%
data1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
 data1_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", data1_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
data1_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %%
data2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data2_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
data2_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %%
data3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data3_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
data3_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# ...

# %%
data4_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data4_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
data4_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# ...

# %%
data5_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data5_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
data5_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# ...

# %%
data6_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data6_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %%
data6_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34418.000000  34683.000000  34557.000000  34396.000000  33663.000000
# mean      83.852089    118.861978     15.366162     55.871075   1323.974423
# ...

# %%
data7_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data7_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %%
data7_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# ...

# %%
data8_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data8_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
data8_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# mean      84.838483    108.991096     18.689242     58.097172   1324.350198
# ...

# %%
data9_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data9_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
data9_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# ...

# %%
data10_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data10_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
data10_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# mean      82.164911    106.363672     14.367615     53.162646   1298.303318
# ...

# %%
data11_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data11_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %%
data11_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34682.000000  34780.000000  34489.000000  33994.000000  33252.000000
# mean      83.374716    110.464618     18.376481     65.258789   1319.353513
# ...

# %%
data12_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
data12_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %%
data12_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Membersihkan data1_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM dengan metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni NE

# %%
wd_mode = data1_df['wd'].mode().iloc[0]
data1_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data1_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: NE

# %%
data1_df['PM2.5'].fillna(data1_df['PM2.5'].mean(), inplace=True)
data1_df['PM10'].fillna(data1_df['PM10'].mean(), inplace=True)
data1_df['SO2'].fillna(data1_df['SO2'].mean(), inplace=True)
data1_df['NO2'].fillna(data1_df['NO2'].mean(), inplace=True)
data1_df['CO'].fillna(data1_df['CO'].mean(), inplace=True)
data1_df['O3'].fillna(data1_df['O3'].mean(), inplace=True)
data1_df['TEMP'].fillna(data1_df['TEMP'].mean(), inplace=True)
data1_df['PRES'].fillna(data1_df['PRES'].mean(), inplace=True)
data1_df['DEWP'].fillna(data1_df['DEWP'].mean(), inplace=True)
data1_df['RAIN'].fillna(data1_df['RAIN'].mean(), inplace=True)
data1_df['WSPM'].fillna(data1_df['WSPM'].mean(), inplace=True)

# %%
data1_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data2_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni NWM

# %%
data2_df['PM2.5'].fillna(data2_df['PM2.5'].mean(), inplace=True)
data2_df['PM10'].fillna(data2_df['PM10'].mean(), inplace=True)
data2_df['SO2'].fillna(data2_df['SO2'].mean(), inplace=True)
data2_df['NO2'].fillna(data2_df['NO2'].mean(), inplace=True)
data2_df['CO'].fillna(data2_df['CO'].mean(), inplace=True)
data2_df['O3'].fillna(data2_df['O3'].mean(), inplace=True)
data2_df['TEMP'].fillna(data2_df['TEMP'].mean(), inplace=True)
data2_df['PRES'].fillna(data2_df['PRES'].mean(), inplace=True)
data2_df['DEWP'].fillna(data2_df['DEWP'].mean(), inplace=True)
data2_df['RAIN'].fillna(data2_df['RAIN'].mean(), inplace=True)
data2_df['WSPM'].fillna(data2_df['WSPM'].mean(), inplace=True)

# %%
wd_mode = data2_df['wd'].mode().iloc[0]
data2_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data2_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: NNW

# %%
data2_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data3_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni NNW

# %%
data3_df['PM2.5'].fillna(data3_df['PM2.5'].mean(), inplace=True)
data3_df['PM10'].fillna(data3_df['PM10'].mean(), inplace=True)
data3_df['SO2'].fillna(data3_df['SO2'].mean(), inplace=True)
data3_df['NO2'].fillna(data3_df['NO2'].mean(), inplace=True)
data3_df['CO'].fillna(data3_df['CO'].mean(), inplace=True)
data3_df['O3'].fillna(data3_df['O3'].mean(), inplace=True)
data3_df['TEMP'].fillna(data3_df['TEMP'].mean(), inplace=True)
data3_df['PRES'].fillna(data3_df['PRES'].mean(), inplace=True)
data3_df['DEWP'].fillna(data3_df['DEWP'].mean(), inplace=True)
data3_df['RAIN'].fillna(data3_df['RAIN'].mean(), inplace=True)
data3_df['WSPM'].fillna(data3_df['WSPM'].mean(), inplace=True)

# %%
wd_mode = data3_df['wd'].mode().iloc[0]
data3_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data3_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: NNW

# %%
data2_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data4_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni ENE

# %%
data4_df['PM2.5'].fillna(data4_df['PM2.5'].mean(), inplace=True)
data4_df['PM10'].fillna(data4_df['PM10'].mean(), inplace=True)
data4_df['SO2'].fillna(data4_df['SO2'].mean(), inplace=True)
data4_df['NO2'].fillna(data4_df['NO2'].mean(), inplace=True)
data4_df['CO'].fillna(data4_df['CO'].mean(), inplace=True)
data4_df['O3'].fillna(data4_df['O3'].mean(), inplace=True)
data4_df['TEMP'].fillna(data4_df['TEMP'].mean(), inplace=True)
data4_df['PRES'].fillna(data4_df['PRES'].mean(), inplace=True)
data4_df['DEWP'].fillna(data4_df['DEWP'].mean(), inplace=True)
data4_df['RAIN'].fillna(data4_df['RAIN'].mean(), inplace=True)
data4_df['WSPM'].fillna(data4_df['WSPM'].mean(), inplace=True)

# %%
data4_df.wd.value_counts()
# Out:
# wd
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: count, dtype: int64

# %%
wd_mode = data4_df['wd'].mode().iloc[0]
data4_df['wd'].fillna(wd_mode, inplace=True)

# %%
data4_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data5_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni NE

# %%
data5_df['PM2.5'].fillna(data5_df['PM2.5'].mean(), inplace=True)
data5_df['PM10'].fillna(data5_df['PM10'].mean(), inplace=True)
data5_df['SO2'].fillna(data5_df['SO2'].mean(), inplace=True)
data5_df['NO2'].fillna(data5_df['NO2'].mean(), inplace=True)
data5_df['CO'].fillna(data5_df['CO'].mean(), inplace=True)
data5_df['O3'].fillna(data5_df['O3'].mean(), inplace=True)
data5_df['TEMP'].fillna(data5_df['TEMP'].mean(), inplace=True)
data5_df['PRES'].fillna(data5_df['PRES'].mean(), inplace=True)
data5_df['DEWP'].fillna(data5_df['DEWP'].mean(), inplace=True)
data5_df['RAIN'].fillna(data5_df['RAIN'].mean(), inplace=True)
data5_df['WSPM'].fillna(data5_df['WSPM'].mean(), inplace=True)

# %%
wd_mode = data5_df['wd'].mode().iloc[0]
data5_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data5_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: NE

# %%
data5_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data6_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni N

# %%
data6_df['PM2.5'].fillna(data6_df['PM2.5'].mean(), inplace=True)
data6_df['PM10'].fillna(data6_df['PM10'].mean(), inplace=True)
data6_df['SO2'].fillna(data6_df['SO2'].mean(), inplace=True)
data6_df['NO2'].fillna(data6_df['NO2'].mean(), inplace=True)
data6_df['CO'].fillna(data6_df['CO'].mean(), inplace=True)
data6_df['O3'].fillna(data6_df['O3'].mean(), inplace=True)
data6_df['TEMP'].fillna(data6_df['TEMP'].mean(), inplace=True)
data6_df['PRES'].fillna(data6_df['PRES'].mean(), inplace=True)
data6_df['DEWP'].fillna(data6_df['DEWP'].mean(), inplace=True)
data6_df['RAIN'].fillna(data6_df['RAIN'].mean(), inplace=True)
data6_df['WSPM'].fillna(data6_df['WSPM'].mean(), inplace=True)

# %%
wd_mode = data6_df['wd'].mode().iloc[0]
data6_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data6_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: N

# %%
data6_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data7_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni NW

# %%
data7_df['PM2.5'].fillna(data7_df['PM2.5'].mean(), inplace=True)
data7_df['PM10'].fillna(data7_df['PM10'].mean(), inplace=True)
data7_df['SO2'].fillna(data7_df['SO2'].mean(), inplace=True)
data7_df['NO2'].fillna(data7_df['NO2'].mean(), inplace=True)
data7_df['CO'].fillna(data7_df['CO'].mean(), inplace=True)
data7_df['O3'].fillna(data7_df['O3'].mean(), inplace=True)
data7_df['TEMP'].fillna(data7_df['TEMP'].mean(), inplace=True)
data7_df['PRES'].fillna(data7_df['PRES'].mean(), inplace=True)
data7_df['DEWP'].fillna(data7_df['DEWP'].mean(), inplace=True)
data7_df['RAIN'].fillna(data7_df['RAIN'].mean(), inplace=True)
data7_df['WSPM'].fillna(data7_df['WSPM'].mean(), inplace=True)

# %%
wd_mode = data7_df['wd'].mode().iloc[0]
data7_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data7_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: NW

# %%
data7_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data8_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni ENE

# %%
data8_df['PM2.5'].fillna(data8_df['PM2.5'].mean(), inplace=True)
data8_df['PM10'].fillna(data8_df['PM10'].mean(), inplace=True)
data8_df['SO2'].fillna(data8_df['SO2'].mean(), inplace=True)
data8_df['NO2'].fillna(data8_df['NO2'].mean(), inplace=True)
data8_df['CO'].fillna(data8_df['CO'].mean(), inplace=True)
data8_df['O3'].fillna(data8_df['O3'].mean(), inplace=True)
data8_df['TEMP'].fillna(data8_df['TEMP'].mean(), inplace=True)
data8_df['PRES'].fillna(data8_df['PRES'].mean(), inplace=True)
data8_df['DEWP'].fillna(data8_df['DEWP'].mean(), inplace=True)
data8_df['RAIN'].fillna(data8_df['RAIN'].mean(), inplace=True)
data8_df['WSPM'].fillna(data8_df['WSPM'].mean(), inplace=True)

# %%
wd_mode = data8_df['wd'].mode().iloc[0]
data8_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data8_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: ENE

# %%
data8_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data9_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni NNE

# %%
data9_df['PM2.5'].fillna(data9_df['PM2.5'].mean(), inplace=True)
data9_df['PM10'].fillna(data9_df['PM10'].mean(), inplace=True)
data9_df['SO2'].fillna(data9_df['SO2'].mean(), inplace=True)
data9_df['NO2'].fillna(data9_df['NO2'].mean(), inplace=True)
data9_df['CO'].fillna(data9_df['CO'].mean(), inplace=True)
data9_df['O3'].fillna(data9_df['O3'].mean(), inplace=True)
data9_df['TEMP'].fillna(data9_df['TEMP'].mean(), inplace=True)
data9_df['PRES'].fillna(data9_df['PRES'].mean(), inplace=True)
data9_df['DEWP'].fillna(data9_df['DEWP'].mean(), inplace=True)
data9_df['RAIN'].fillna(data9_df['RAIN'].mean(), inplace=True)
data9_df['WSPM'].fillna(data9_df['WSPM'].mean(), inplace=True)

# %%
wd_mode = data9_df['wd'].mode().iloc[0]
data9_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data9_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: NNE

# %%
data9_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data10_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni ENE

# %%
data10_df['PM2.5'].fillna(data10_df['PM2.5'].mean(), inplace=True)
data10_df['PM10'].fillna(data10_df['PM10'].mean(), inplace=True)
data10_df['SO2'].fillna(data10_df['SO2'].mean(), inplace=True)
data10_df['NO2'].fillna(data10_df['NO2'].mean(), inplace=True)
data10_df['CO'].fillna(data10_df['CO'].mean(), inplace=True)
data10_df['O3'].fillna(data10_df['O3'].mean(), inplace=True)
data10_df['TEMP'].fillna(data10_df['TEMP'].mean(), inplace=True)
data10_df['PRES'].fillna(data10_df['PRES'].mean(), inplace=True)
data10_df['DEWP'].fillna(data10_df['DEWP'].mean(), inplace=True)
data10_df['RAIN'].fillna(data10_df['RAIN'].mean(), inplace=True)
data10_df['WSPM'].fillna(data10_df['WSPM'].mean(), inplace=True)

# %%
wd_mode = data10_df['wd'].mode().iloc[0]
data10_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data10_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: ENE

# %%
data10_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data11_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni NE

# %%
data11_df['PM2.5'].fillna(data11_df['PM2.5'].mean(), inplace=True)
data11_df['PM10'].fillna(data11_df['PM10'].mean(), inplace=True)
data11_df['SO2'].fillna(data11_df['SO2'].mean(), inplace=True)
data11_df['NO2'].fillna(data11_df['NO2'].mean(), inplace=True)
data11_df['CO'].fillna(data11_df['CO'].mean(), inplace=True)
data11_df['O3'].fillna(data11_df['O3'].mean(), inplace=True)
data11_df['TEMP'].fillna(data11_df['TEMP'].mean(), inplace=True)
data11_df['PRES'].fillna(data11_df['PRES'].mean(), inplace=True)
data11_df['DEWP'].fillna(data11_df['DEWP'].mean(), inplace=True)
data11_df['RAIN'].fillna(data11_df['RAIN'].mean(), inplace=True)
data11_df['WSPM'].fillna(data11_df['WSPM'].mean(), inplace=True)

# %%
wd_mode = data11_df['wd'].mode().iloc[0]
data11_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data11_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: NE

# %%
data11_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Membersihkan data12_df
# * menangani missing value pada PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, WSPM metode imputation menggunakan nilai mean
# * menangani missing value pada wd menggunakan nilai yang dominan yakni NE

# %%
data12_df['PM2.5'].fillna(data12_df['PM2.5'].mean(), inplace=True)
data12_df['PM10'].fillna(data12_df['PM10'].mean(), inplace=True)
data12_df['SO2'].fillna(data12_df['SO2'].mean(), inplace=True)
data12_df['NO2'].fillna(data12_df['NO2'].mean(), inplace=True)
data12_df['CO'].fillna(data12_df['CO'].mean(), inplace=True)
data12_df['O3'].fillna(data12_df['O3'].mean(), inplace=True)
data12_df['TEMP'].fillna(data12_df['TEMP'].mean(), inplace=True)
data12_df['PRES'].fillna(data12_df['PRES'].mean(), inplace=True)
data12_df['DEWP'].fillna(data12_df['DEWP'].mean(), inplace=True)
data12_df['RAIN'].fillna(data12_df['RAIN'].mean(), inplace=True)
data12_df['WSPM'].fillna(data12_df['WSPM'].mean(), inplace=True)

# %%
wd_mode = data12_df['wd'].mode().iloc[0]
data12_df['wd'].fillna(wd_mode, inplace=True)

# %%
mode_wd = data12_df['wd'].value_counts().idxmax()
print(f"Arah angin yang paling sering muncul: {mode_wd}")
# Out:
# Arah angin yang paling sering muncul: NE

# %%
data12_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
all_df = pd.concat(
    [data1_df,
    data2_df,
    data3_df,
    data4_df,
    data5_df,
    data6_df,
    data7_df,
    data8_df,
    data9_df,
    data10_df,
    data11_df,
    data12_df]).reset_index()
all_df.head(10)
# Out:
#    index  No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0      0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1      1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2      2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3      3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4      4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# 5      5   6  2013      3    1     5    5.0   5.0  18.0  18.0  400.0  66.0
# 6      6   7  2013      3    1     6    3.0   3.0  18.0  32.0  500.0  50.0
# 7      7   8  2013      3    1     7    3.0   6.0  19.0  41.0  500.0  43.0
# 8      8   9  2013      3    1     8    3.0   6.0  16.0  43.0  500.0  45.0
# 9      9  10  2013      3    1     9    3.0   8.0  12.0  28.0  400.0  59.0
#
#    TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# 0  -0.7  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# ...

# %%
all_df['date'] = pd.to_datetime(all_df[['year', 'month', 'day']])
all_df = all_df = all_df.drop(['day', 'month', 'year'], axis=1)
all_df.head(12)
# Out:
#     index  No  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  \
# 0       0   1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7  1023.0 -18.8
# 1       1   2     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1  1023.2 -18.2
# 2       2   3     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1  1023.5 -18.2
# 3       3   4     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4  1024.5 -19.4
# 4       4   5     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0  1025.2 -19.5
# 5       5   6     5    5.0   5.0  18.0  18.0  400.0  66.0  -2.2  1025.6 -19.6
# 6       6   7     6    3.0   3.0  18.0  32.0  500.0  50.0  -2.6  1026.5 -19.1
# 7       7   8     7    3.0   6.0  19.0  41.0  500.0  43.0  -1.6  1027.4 -19.1
# 8       8   9     8    3.0   6.0  16.0  43.0  500.0  45.0   0.1  1028.3 -19.2
# 9       9  10     9    3.0   8.0  12.0  28.0  400.0  59.0   1.2  1028.5 -19.3
# 10     10  11    10    3.0   6.0   9.0  12.0  400.0  72.0   1.9  1028.2 -19.4
# ...

# %%
# cek kesesuaian jam yakni 24 jam
all_df.head(26)
# Out:
#     index  No  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  \
# 0       0   1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7  1023.0 -18.8
# 1       1   2     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1  1023.2 -18.2
# 2       2   3     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1  1023.5 -18.2
# 3       3   4     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4  1024.5 -19.4
# 4       4   5     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0  1025.2 -19.5
# 5       5   6     5    5.0   5.0  18.0  18.0  400.0  66.0  -2.2  1025.6 -19.6
# 6       6   7     6    3.0   3.0  18.0  32.0  500.0  50.0  -2.6  1026.5 -19.1
# 7       7   8     7    3.0   6.0  19.0  41.0  500.0  43.0  -1.6  1027.4 -19.1
# 8       8   9     8    3.0   6.0  16.0  43.0  500.0  45.0   0.1  1028.3 -19.2
# 9       9  10     9    3.0   8.0  12.0  28.0  400.0  59.0   1.2  1028.5 -19.3
# 10     10  11    10    3.0   6.0   9.0  12.0  400.0  72.0   1.9  1028.2 -19.4
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore all_df

# %%
all_df.sample(12)
# Out:
#         index     No  hour  PM2.5   PM10    SO2    NO2      CO     O3  TEMP  \
# 177958   2638   2639    22   56.0  148.0    5.0   87.0   900.0   80.0  26.9
# 231274  20890  20891    10   29.0   29.0    2.0   14.0   800.0   76.0  23.1
# 91311   21183  21184    15   11.0   25.0    2.0    6.0   500.0  167.0  29.2
# 281884   1372   1373     4   66.0   82.0   52.0   92.0  1300.0    4.0  10.0
# 331970  16394  16395     2  113.0  113.0   23.0   80.0  3100.0    8.0  -3.4
# 52245   17181  17182    21  242.0  242.0   55.0   65.0  2700.0   69.0   3.0
# 262518  17070  17071     6  128.0  128.0   56.0   98.0  2600.0    2.0  -6.0
# 326826  11250  11251    18   15.0   24.0    4.0   29.0   400.0  144.0  30.9
# 203671  28351  28352     7    6.0    8.0    2.0   19.0   300.0  102.0  20.1
# 420188  34484  34485    20  389.0  389.0   42.0  153.0   400.0    7.0   7.7
# 386783   1079   1080    23  148.0  177.0   31.0   55.0  2100.0   33.0  11.1
# ...

# %%
all_df.describe(include='all')
# Out:
#                 index             No           hour          PM2.5  \
# count   420768.000000  420768.000000  420768.000000  420768.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     17531.500000   17532.500000      11.500000      79.780235
# min          0.000000       1.000000       0.000000       2.000000
# 25%       8765.750000    8766.750000       5.750000      21.000000
# 50%      17531.500000   17532.500000      11.500000      57.000000
# 75%      26297.250000   26298.250000      17.250000     109.000000
# max      35063.000000   35064.000000      23.000000     999.000000
# std      10122.116943   10122.116943       6.922195      79.984694
#
#                  PM10            SO2            NO2            CO  \
# count   420768.000000  420768.000000  420768.000000  420768.00000
# ...

# %%
all_df.head(10)
# Out:
#    index  No  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  \
# 0      0   1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7  1023.0 -18.8
# 1      1   2     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1  1023.2 -18.2
# 2      2   3     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1  1023.5 -18.2
# 3      3   4     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4  1024.5 -19.4
# 4      4   5     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0  1025.2 -19.5
# 5      5   6     5    5.0   5.0  18.0  18.0  400.0  66.0  -2.2  1025.6 -19.6
# 6      6   7     6    3.0   3.0  18.0  32.0  500.0  50.0  -2.6  1026.5 -19.1
# 7      7   8     7    3.0   6.0  19.0  41.0  500.0  43.0  -1.6  1027.4 -19.1
# 8      8   9     8    3.0   6.0  16.0  43.0  500.0  45.0   0.1  1028.3 -19.2
# 9      9  10     9    3.0   8.0  12.0  28.0  400.0  59.0   1.2  1028.5 -19.3
#
#    RAIN   wd  WSPM       station       date
# 0   0.0  NNW   4.4  Aotizhongxin 2013-03-01
# ...

# %%
all_df.tail(10)
# Out:
#         index     No  hour  PM2.5  PM10        SO2       NO2           CO  \
# 420758  35054  35055    14    3.0   6.0  17.148603   5.00000  1370.395031
# 420759  35055  35056    15   11.0  21.0   2.000000   5.00000   200.000000
# 420760  35056  35057    16    6.0  20.0   3.000000  55.52956   200.000000
# 420761  35057  35058    17   11.0  23.0   3.000000  12.00000   300.000000
# 420762  35058  35059    18   11.0  30.0   2.000000  16.00000   300.000000
# 420763  35059  35060    19   11.0  32.0   3.000000  24.00000   400.000000
# 420764  35060  35061    20   13.0  32.0   3.000000  41.00000   500.000000
# 420765  35061  35062    21   14.0  28.0   4.000000  38.00000   500.000000
# 420766  35062  35063    22   12.0  23.0   4.000000  30.00000   400.000000
# 420767  35063  35064    23   13.0  19.0   4.000000  38.00000   600.000000
#
#                O3  TEMP    PRES  DEWP  RAIN   wd  WSPM        station  \
# 420758  82.000000  14.6  1013.3 -15.6   0.0    N   3.6  Wanshouxigong
# ...

# %% [markdown]
# ### Explore kadar CO di berbagai kota

# %%
# mencari rata-rata kadar CO di berbagai Kota
co_mean_df = all_df.groupby(by=["date"]).agg({
    "CO": "mean"
})
co_mean_df.head(10)
# Out:
#                      CO
# date
# 2013-03-01   424.491009
# 2013-03-02   952.975013
# 2013-03-03  1770.291306
# 2013-03-04   731.871577
# 2013-03-05  2024.739374
# 2013-03-06  2782.337836
# 2013-03-07  3761.482278
# 2013-03-08  2846.765522
# 2013-03-09  1129.807402
# 2013-03-10   773.756799

# %% [markdown]
# ### Explore kadar PM10 di berbagai kota

# %%
# mencari rata-rata kadar polutan PM10 di berbagai Kota
pm10_df = all_df.groupby(by="station").agg({
    "PM10":  "mean"
}).sort_values(by="PM10",ascending=False).reset_index()
pm10_df.head(12)
# Out:
#           station        PM10
# 0         Gucheng  118.861978
# 1   Wanshouxigong  112.223459
# 2          Wanliu  110.464618
# 3          Dongsi  110.336742
# 4    Aotizhongxin  110.060391
# 5        Guanyuan  109.023303
# 6    Nongzhanguan  108.991096
# 7         Tiantan  106.363672
# 8          Shunyi   98.737026
# 9       Changping   94.657871
# 10        Huairou   91.482690
# 11       Dingling   83.739723

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Tren kadar CO di berbagai kota di China dalam kurun waktu 2013-2017

# %%
co_mean_monthly_df = all_df.resample(rule='M',on='date').agg({
    "CO":"mean"
}).reset_index()
co_mean_monthly_df.head()
# Out:
#         date           CO
# 0 2013-03-31  1443.300893
# 1 2013-04-30   918.776573
# 2 2013-05-31  1036.725339
# 3 2013-06-30  1389.386378
# 4 2013-07-31  1013.490221

# %%
plt.figure(figsize=(15,5))
plt.plot(co_mean_monthly_df['date'],co_mean_monthly_df['CO'], marker= 'o',linewidth = 2,color = "#72BCD4")
for i, txt in enumerate(co_mean_monthly_df['CO']):
    rounded_value = round(txt, 1) #membulatkan nilai sampai 1 angka di belakang koma
    if txt > 2000: # menuliskan nilai pada titik memiliki nilai >2000
        plt.annotate(rounded_value, (co_mean_monthly_df['date'][i], co_mean_monthly_df['CO'][i]), textcoords="offset points", xytext=(0,3), ha='center', fontsize=10)
    elif txt < 750: # menuliskan nilai pada titik memiliki nilai <750
        plt.annotate(rounded_value, (co_mean_monthly_df['date'][i], co_mean_monthly_df['CO'][i]), textcoords="offset points", xytext=(0,-12), ha='center', fontsize=10)
plt.title("Diagram Rata-Rata Kadar CO Bulanan")
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10) 
plt.show()

# %%
# mencari kadar CO terendah tiap tahun
co_mean_monthly_df.loc[co_mean_monthly_df.groupby(co_mean_monthly_df['date'].dt.year)['CO'].idxmin()]
# Out:
#          date           CO
# 5  2013-08-31   912.606721
# 15 2014-06-30   807.288655
# 26 2015-05-31   726.377285
# 38 2016-05-31   668.898049
# 47 2017-02-28  1159.371903

# %% [markdown]
# Kadar CO terendah terjadi pada bulan Mei 2016 yaitu 668,9. Data ini diambil dari rata-rata kadar CO untuk seluruh kota di China (sesuai data). Adapun untuk kadar CO di udara terendah dalam tahunan yaitu seperti berikut:
# * Tahun 2013 kadar CO terendah terjadi pada bulan Agustus
# * Tahun 2014 kadar CO terendah terjadi pada bulan Juni
# * Tahun 2015 kadar CO terendah terjadi pada bulan Mei
# * Tahun 2016 kadar CO terendah terjadi pada bulan Mei, dan
# * Tahun 2017 kadar CO terendah terjadi pada bulan Februari (karena data yang diperoleh hanya sampai Februari 2017)

# %%
# mencari kadar CO tertinggi tiap tahun
co_mean_monthly_df.loc[co_mean_monthly_df.groupby(co_mean_monthly_df['date'].dt.year)['CO'].idxmax()]
# Out:
#          date           CO
# 9  2013-12-31  1679.504737
# 11 2014-02-28  2039.263914
# 33 2015-12-31  2710.662506
# 45 2016-12-31  2398.791919
# 46 2017-01-31  1981.224208

# %% [markdown]
# Kadar CO paling tinggi terjadi pada bulan Desember 2015 yaitu 2701,66. Data ini diambil dari rata-rata kadar CO untuk seluruh kota di China (sesuai data). Adapun untuk kadar CO di udara paling tinggi dalam tahunan yaitu seperti berikut:
# * Tahun 2013 kadar CO tertinggi terjadi pada bulan Desember
# * Tahun 2014 kadar CO tertinggi terjadi pada bulan Februari
# * Tahun 2015 kadar CO tertinggi terjadi pada bulan Desember
# * Tahun 2016 kadar CO tertinggi terjadi pada bulan Desember, dan
# * Tahun 2017 kadar CO tertinggi terjadi pada bulan Januari (karena data yang diperoleh hanya sampai Februari 2017)

# %% [markdown]
# ### Pertanyaan 2: Kota yang paling baik dan paling buruk kondisi udaranya berdasarkan pengukuran konsentrasi PM10 di udara

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize = (24,6))

color1 = ["#FFBFBF", "#EDE9D5", "#EDE9D5", "#EDE9D5", "#EDE9D5"]
color2 = ["#A8DF8E", "#EDE9D5", "#EDE9D5", "#EDE9D5", "#EDE9D5"]

sns.barplot(x="PM10", y="station", data=pm10_df.head(5), palette=color1, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Kota Berpolutan PM10 Terbanyak", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="PM10", y="station", data = pm10_df.sort_values(by="PM10", ascending=True).head(5), palette=color2, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Kota Berpolutan PM10 Paling Sedikit", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Kota Berpolutan PM10", fontsize=20)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1984\1890594577.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="PM10", y="station", data=pm10_df.head(5), palette=color1, ax=ax[0])
# C:\Users\USER\AppData\Local\Temp\ipykernel_1984\1890594577.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="PM10", y="station", data = pm10_df.sort_values(by="PM10", ascending=True).head(5), palette=color2, ax=ax[1])

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * Conclusion pertanyaan 1:
# Kadar CO rata-rata bulanan cenderung meningkat dari bulan Oktober dan memuncak pada bulan Desember - Februari. Puncak paling tinggi terjadi di bulan Desember 2015 dengan kadar 2701,7. Dari hasil penelusuran, Desember-Februari merupakan musim dingin di China, sehingga penduduk mungkin menggunakan pemanas rumah dengan pembakaran bahan bakar. Hal ini yang dapat meningkatkan kadar CO.
#
# * Conclusion pertanyaan 2:
# Gucheng memiliki kadar polutan PM10 terbanyak di udara yang mencapai 118,86, paling banyak di antara 11 kota lainnya. Sedangkan Dingling menempati kota terbersih udanya dalam hal polutan PM10. Dingling memiliki polutan PM10 sebanyak 83,74.

# %%
all_df.to_csv("main_data.csv", index=False)
